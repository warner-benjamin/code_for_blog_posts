# %%
! nvidia-smi
# Out:
# Sun Jul 18 04:43:24 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
! pip install fastcore --upgrade -qq
! pip install fastai --upgrade -qq
! pip install git+https://github.com/thomasbrandon/mish-cuda -qq
# Out:
#      |████████████████████████████████| 61kB 5.7MB/s
#      |████████████████████████████████| 194kB 7.6MB/s
#   Building wheel for mish-cuda (setup.py) ... done

# %%
from fastai.vision.all import *
import fastai
from sys import exit
from operator import itemgetter
import re
import torch
from torch.nn import functional as F
import numpy as np
from mish_cuda import MishCudaFunction

# %%
def scale(val, spec="#0.4G"):
    PREFIXES = np.array([c for c in u"yzafpnµm kMGTPEZY"])
    exp = np.int8(np.log10(np.abs(val)) // 3 * 3 * np.sign(val))
    val /= 10.**exp
    prefix = PREFIXES[exp//3 + len(PREFIXES)//2]
    return f"{val:{spec}}{prefix}"

def display_times(times):
    return f"{scale(times.mean())}s ± {scale(times.std())}s, {scale(times.min())}s, {scale(times.max())}s"

def profile_cuda(func, inp, n_repeat=100, warmup=10):
    fwd_times,bwd_times = [],[]
    for i in range(n_repeat + warmup):
        start,end = (torch.cuda.Event(enable_timing=True) for _ in range(2))
        start.record()
        res = func(inp)
        end.record()
        torch.cuda.synchronize()
        if i >= warmup: fwd_times.append(start.elapsed_time(end))
        start,end = (torch.cuda.Event(enable_timing=True) for _ in range(2))
        inp = inp.clone().requires_grad_()
        y = func(inp)
        l = y.mean()
        start.record()
        _ = torch.autograd.grad(l, inp)
        end.record()
        torch.cuda.synchronize()
        if i >= warmup: bwd_times.append(start.elapsed_time(end))
    return (np.array(fwd_times)/1000, # Elapsed time is in ms
            np.array(bwd_times)/1000)

mish_pt = lambda x: x.mul(torch.tanh(F.softplus(x)))

def profile(device='cuda', n_repeat=100, warmup=10, size='(16,10,256,256)', baseline=True, types='all'):
    if types == 'all': 
        dtypes = [torch.float16, torch.bfloat16, torch.float32, torch.float64]
    else:
        if not hasattr(torch, types): exit("Invalid data type, expected torch type or 'all', got {types}")
        dtypes = [getattr(torch, types)]
    dev = torch.device(type=device)
    sz_str = size.replace(' ','')
    if not re.match(r"[\(\[]\d+(,\d+)*[\)\]]", sz_str):
        exit("Badly formatted size, should be a list or tuple such as \"(1,2,3)\".")
    sz = list(map(int, sz_str[1:-1].split(',')))
    print(f"Profiling over {n_repeat} runs after {warmup} warmup runs.")
    for dtype in dtypes:
        if len(dtypes) > 1:
            print(f"Testing on {dtype}:")
            ind = ' '
        else: ind = ''
        inp = torch.randn(*sz, dtype=dtype, device=dev)
        timings = []
        funcs = {}
        funcs.update(relu = torch.nn.functional.relu, 
                     leaky_relu = torch.nn.functional.leaky_relu,
                     softplus = torch.nn.functional.softplus,
                     silu_jit = fastai.layers.swish,
                     silu_native = torch.nn.functional.silu,
                     mish_naive = mish_pt,
                     mish_jit = fastai.layers.mish,
                     mish_cuda = MishCudaFunction.apply,
                     mish_native = torch.nn.functional.mish)
        if device=='cpu': funcs.pop('mish_cuda')
        max_name = max(map(len, funcs.keys())) + 6
        for (name,func) in funcs.items():
            if device=='cuda':
                if (name=='mish_cuda') and (dtype==torch.bfloat16):
                    pass
                else: fwd_times,bwd_times = profile_cuda(func, inp, n_repeat, warmup)
            print(ind+(name+'_fwd:').ljust(max_name) + display_times(fwd_times))
            print(ind+(name+'_bwd:').ljust(max_name) + display_times(bwd_times))
            torch.cuda.empty_cache()

# %% [markdown]
# # 100 iterations

# %%
profile('cuda')
# Out:
# Profiling over 100 runs after 10 warmup runs.
# Testing on torch.float16:
#  relu_fwd:        114.3µs ± 15.35µs, 106.2µs, 236.0µs
#  relu_bwd:        401.8µs ± 502.5µs, 327.6µs, 5.170ms
#  leaky_relu_fwd:  104.9µs ± 15.58µs, 101.1µs, 257.4µs
#  leaky_relu_bwd:  316.7µs ± 15.29µs, 314.0µs, 468.8µs
#  softplus_fwd:    225.3µs ± 61.01µs, 214.5µs, 831.2µs
#  softplus_bwd:    449.3µs ± 65.98µs, 436.4µs, 1.091ms
#  silu_jit_fwd:    181.8µs ± 21.29µs, 177.0µs, 363.1µs
#  silu_jit_bwd:    364.7µs ± 769.8ns, 362.7µs, 366.6µs
#  silu_native_fwd: 128.5µs ± 4.818µs, 124.5µs, 148.4µs
#  silu_native_bwd: 333.0µs ± 183.8µs, 309.5µs, 2.113ms
#  mish_naive_fwd:  434.0µs ± 25.70µs, 428.3µs, 686.8µs
#  mish_naive_bwd:  932.5µs ± 213.1µs, 900.4µs, 2.707ms
#  mish_jit_fwd:    378.0µs ± 7.118µs, 368.3µs, 400.0µs
#  mish_jit_bwd:    625.6µs ± 307.2µs, 590.4µs, 3.681ms
#  mish_cuda_fwd:   277.4µs ± 3.832µs, 273.4µs, 305.4µs
#  mish_cuda_bwd:   478.6µs ± 467.8ns, 477.8µs, 480.2µs
#  mish_native_fwd: 206.1µs ± 44.46µs, 197.5µs, 644.7µs
#  mish_native_bwd: 446.4µs ± 26.33µs, 441.5µs, 678.7µs
# Testing on torch.bfloat16:
#  relu_fwd:        107.4µs ± 2.817µs, 105.2µs, 119.2µs
#  relu_bwd:        307.4µs ± 5.838µs, 305.6µs, 359.3µs
#  leaky_relu_fwd:  103.2µs ± 3.106µs, 100.8µs, 122.3µs
#  leaky_relu_bwd:  307.4µs ± 2.372µs, 306.5µs, 330.7µs
#  softplus_fwd:    240.4µs ± 32.73µs, 235.0µs, 563.8µs
#  softplus_bwd:    429.4µs ± 328.5µs, 395.8µs, 3.698ms
#  silu_jit_fwd:    273.8µs ± 6.896µs, 268.6µs, 311.7µs
#  silu_jit_bwd:    909.9µs ± 114.8µs, 896.0µs, 2.052ms
#  silu_native_fwd: 143.6µs ± 5.667µs, 138.5µs, 175.3µs
#  silu_native_bwd: 360.0µs ± 235.9µs, 314.3µs, 2.393ms
#  mish_naive_fwd:  463.9µs ± 61.92µs, 454.0µs, 1.079ms
#  mish_naive_bwd:  884.3µs ± 212.4µs, 861.4µs, 2.998ms
#  mish_jit_fwd:    472.1µs ± 5.339µs, 467.2µs, 490.6µs
#  mish_jit_bwd:    1.371ms ± 283.2µs, 1.329ms, 3.923ms
#  mish_cuda_fwd:   472.1µs ± 5.339µs, 467.2µs, 490.6µs
#  mish_cuda_bwd:   1.371ms ± 283.2µs, 1.329ms, 3.923ms
#  mish_native_fwd: 218.0µs ± 12.73µs, 212.5µs, 338.4µs
#  mish_native_bwd: 511.6µs ± 231.6µs, 453.4µs, 1.670ms
# Testing on torch.float32:
#  relu_fwd:        189.9µs ± 47.20µs, 182.3µs, 658.5µs
#  relu_bwd:        468.4µs ± 258.1µs, 441.3µs, 3.037ms
#  leaky_relu_fwd:  185.1µs ± 40.48µs, 177.8µs, 586.2µs
#  leaky_relu_bwd:  471.9µs ± 223.4µs, 441.4µs, 2.584ms
#  softplus_fwd:    208.0µs ± 47.14µs, 197.9µs, 674.7µs
#  softplus_bwd:    465.0µs ± 215.5µs, 442.1µs, 2.609ms
#  silu_jit_fwd:    433.0µs ± 27.39µs, 423.3µs, 698.0µs
#  silu_jit_bwd:    1.574ms ± 286.1µs, 1.525ms, 4.144ms
#  silu_native_fwd: 181.3µs ± 6.474µs, 176.3µs, 224.7µs
#  silu_native_bwd: 447.2µs ± 40.24µs, 441.3µs, 847.6µs
#  mish_naive_fwd:  595.9µs ± 19.62µs, 586.6µs, 773.0µs
#  mish_naive_bwd:  1.365ms ± 69.41µs, 1.352ms, 1.946ms
#  mish_jit_fwd:    605.0µs ± 6.587µs, 599.2µs, 641.4µs
#  mish_jit_bwd:    2.148ms ± 401.9µs, 2.090ms, 5.812ms
#  mish_cuda_fwd:   283.4µs ± 4.760µs, 278.7µs, 300.0µs
#  mish_cuda_bwd:   490.5µs ± 21.11µs, 485.7µs, 700.1µs
#  mish_native_fwd: 208.9µs ± 40.96µs, 199.9µs, 610.7µs
#  mish_native_bwd: 497.6µs ± 218.6µs, 466.3µs, 2.442ms
# Testing on torch.float64:
#  relu_fwd:        392.7µs ± 4.992µs, 386.7µs, 415.8µs
#  relu_bwd:        721.7µs ± 204.1µs, 694.0µs, 2.732ms
#  leaky_relu_fwd:  390.2µs ± 8.284µs, 382.8µs, 447.1µs
#  leaky_relu_bwd:  707.8µs ± 79.32µs, 694.6µs, 1.455ms
#  softplus_fwd:    489.0µs ± 16.10µs, 482.1µs, 636.3µs
#  softplus_bwd:    813.3µs ± 180.5µs, 783.9µs, 2.473ms
#  silu_jit_fwd:    1.006ms ± 6.768µs, 995.1µs, 1.026ms
#  silu_jit_bwd:    3.258ms ± 112.6µs, 3.239ms, 4.378ms
#  silu_native_fwd: 382.9µs ± 7.561µs, 377.0µs, 435.7µs
#  silu_native_bwd: 692.6µs ± 2.279µs, 688.0µs, 709.7µs
#  mish_naive_fwd:  1.343ms ± 8.757µs, 1.332ms, 1.403ms
#  mish_naive_bwd:  2.828ms ± 390.0µs, 2.766ms, 5.945ms
#  mish_jit_fwd:    1.355ms ± 6.540µs, 1.346ms, 1.385ms
#  mish_jit_bwd:    4.575ms ± 212.3µs, 4.541ms, 6.687ms
#  mish_cuda_fwd:   717.0µs ± 4.584µs, 713.2µs, 746.3µs
#  mish_cuda_bwd:   976.7µs ± 611.9ns, 975.2µs, 979.6µs
#  mish_native_fwd: 645.9µs ± 5.989µs, 639.8µs, 669.6µs
#  mish_native_bwd: 976.7µs ± 201.0µs, 943.0µs, 2.408ms

# %%
profile('cuda', size='(64,10,256,256)')
# Out:
# Profiling over 100 runs after 10 warmup runs.
# Testing on torch.float16:
#  relu_fwd:        345.1µs ± 5.984µs, 337.7µs, 367.6µs
#  relu_bwd:        1.257ms ± 201.6µs, 1.205ms, 2.986ms
#  leaky_relu_fwd:  343.0µs ± 30.66µs, 334.0µs, 643.7µs
#  leaky_relu_bwd:  1.213ms ± 59.66µs, 1.204ms, 1.806ms
#  softplus_fwd:    791.0µs ± 4.405µs, 787.4µs, 808.7µs
#  softplus_bwd:    1.638ms ± 127.4µs, 1.624ms, 2.906ms
#  silu_jit_fwd:    609.4µs ± 6.577µs, 603.5µs, 637.8µs
#  silu_jit_bwd:    1.430ms ± 12.35µs, 1.422ms, 1.550ms
#  silu_native_fwd: 434.2µs ± 23.30µs, 426.4µs, 659.0µs
#  silu_native_bwd: 1.239ms ± 300.0µs, 1.206ms, 4.223ms
#  mish_naive_fwd:  1.623ms ± 9.061µs, 1.616ms, 1.690ms
#  mish_naive_bwd:  3.512ms ± 620.0µs, 3.439ms, 9.614ms
#  mish_jit_fwd:    1.362ms ± 8.539µs, 1.347ms, 1.408ms
#  mish_jit_bwd:    2.329ms ± 4.493µs, 2.319ms, 2.335ms
#  mish_cuda_fwd:   1.011ms ± 11.01µs, 1.004ms, 1.110ms
#  mish_cuda_bwd:   1.883ms ± 1.018µs, 1.882ms, 1.891ms
#  mish_native_fwd: 731.8µs ± 45.41µs, 720.1µs, 1.135ms
#  mish_native_bwd: 1.774ms ± 361.7µs, 1.736ms, 5.372ms
# Testing on torch.bfloat16:
#  relu_fwd:        350.4µs ± 71.64µs, 338.5µs, 1.062ms
#  relu_bwd:        1.239ms ± 480.5µs, 1.189ms, 6.020ms
#  leaky_relu_fwd:  343.5µs ± 30.19µs, 335.0µs, 638.8µs
#  leaky_relu_bwd:  1.248ms ± 354.3µs, 1.190ms, 3.887ms
#  softplus_fwd:    878.7µs ± 6.520µs, 872.6µs, 905.4µs
#  softplus_bwd:    1.571ms ± 164.9µs, 1.547ms, 2.857ms
#  silu_jit_fwd:    964.7µs ± 7.092µs, 956.3µs, 985.0µs
#  silu_jit_bwd:    3.571ms ± 380.6µs, 3.497ms, 6.094ms
#  silu_native_fwd: 494.2µs ± 12.04µs, 489.3µs, 602.1µs
#  silu_native_bwd: 1.260ms ± 335.6µs, 1.215ms, 4.511ms
#  mish_naive_fwd:  1.730ms ± 6.411µs, 1.723ms, 1.754ms
#  mish_naive_bwd:  3.378ms ± 85.90µs, 3.368ms, 4.233ms
#  mish_jit_fwd:    1.742ms ± 6.498µs, 1.735ms, 1.763ms
#  mish_jit_bwd:    5.200ms ± 1.284µs, 5.197ms, 5.205ms
#  mish_cuda_fwd:   1.742ms ± 6.498µs, 1.735ms, 1.763ms
#  mish_cuda_bwd:   5.200ms ± 1.284µs, 5.197ms, 5.205ms
#  mish_native_fwd: 785.7µs ± 6.729µs, 781.2µs, 834.0µs
#  mish_native_bwd: 1.777ms ± 387.5ns, 1.777ms, 1.778ms
# Testing on torch.float32:
#  relu_fwd:        653.7µs ± 6.094µs, 647.8µs, 671.1µs
#  relu_bwd:        1.757ms ± 251.0µs, 1.728ms, 4.255ms
#  leaky_relu_fwd:  648.2µs ± 3.682µs, 644.7µs, 662.1µs
#  leaky_relu_bwd:  1.760ms ± 279.3µs, 1.730ms, 4.538ms
#  softplus_fwd:    732.8µs ± 7.060µs, 725.2µs, 770.6µs
#  softplus_bwd:    1.733ms ± 972.9ns, 1.731ms, 1.737ms
#  silu_jit_fwd:    1.571ms ± 7.414µs, 1.562ms, 1.593ms
#  silu_jit_bwd:    6.041ms ± 156.0µs, 6.022ms, 7.594ms
#  silu_native_fwd: 647.7µs ± 4.257µs, 643.6µs, 665.5µs
#  silu_native_bwd: 1.747ms ± 140.1µs, 1.730ms, 3.141ms
#  mish_naive_fwd:  2.263ms ± 6.280µs, 2.255ms, 2.292ms
#  mish_naive_bwd:  5.344ms ± 1.697µs, 5.341ms, 5.348ms
#  mish_jit_fwd:    2.278ms ± 7.516µs, 2.268ms, 2.302ms
#  mish_jit_bwd:    8.310ms ± 495.3µs, 8.255ms, 13.24ms
#  mish_cuda_fwd:   1.035ms ± 5.540µs, 1.027ms, 1.067ms
#  mish_cuda_bwd:   1.905ms ± 2.572µs, 1.901ms, 1.924ms
#  mish_native_fwd: 732.3µs ± 5.943µs, 725.8µs, 750.5µs
#  mish_native_bwd: 1.850ms ± 234.3µs, 1.823ms, 4.182ms
# Testing on torch.float64:
#  relu_fwd:        1.470ms ± 5.944µs, 1.459ms, 1.484ms
#  relu_bwd:        2.777ms ± 66.01µs, 2.763ms, 3.433ms
#  leaky_relu_fwd:  1.465ms ± 6.305µs, 1.455ms, 1.491ms
#  leaky_relu_bwd:  2.768ms ± 2.883µs, 2.760ms, 2.775ms
#  softplus_fwd:    1.861ms ± 5.550µs, 1.854ms, 1.886ms
#  softplus_bwd:    3.130ms ± 4.550µs, 3.118ms, 3.143ms
#  silu_jit_fwd:    3.866ms ± 12.36µs, 3.843ms, 3.901ms
#  silu_jit_bwd:    12.86ms ± 9.264µs, 12.84ms, 12.88ms
#  silu_native_fwd: 1.449ms ± 6.035µs, 1.440ms, 1.473ms
#  silu_native_bwd: 2.749ms ± 46.87µs, 2.738ms, 3.215ms
#  mish_naive_fwd:  5.247ms ± 7.280µs, 5.235ms, 5.269ms
#  mish_naive_bwd:  11.01ms ± 8.017µs, 10.99ms, 11.03ms
#  mish_jit_fwd:    5.260ms ± 8.579µs, 5.245ms, 5.305ms
#  mish_jit_bwd:    18.06ms ± 8.800µs, 18.04ms, 18.08ms
#  mish_cuda_fwd:   2.761ms ± 4.353µs, 2.755ms, 2.785ms
#  mish_cuda_bwd:   3.939ms ± 638.1µs, 3.873ms, 10.29ms
#  mish_native_fwd: 2.483ms ± 4.603µs, 2.478ms, 2.500ms
#  mish_native_bwd: 3.754ms ± 792.4ns, 3.753ms, 3.756ms

# %% [markdown]
# # 50 iterations

# %%
profile('cuda', n_repeat=50)
# Out:
# Profiling over 50 runs after 10 warmup runs.
# Testing on torch.float16:
#  relu_fwd:        108.2µs ± 4.445µs, 103.5µs, 124.4µs
#  relu_bwd:        346.9µs ± 73.09µs, 330.0µs, 817.3µs
#  leaky_relu_fwd:  103.6µs ± 3.178µs, 99.84µs, 118.0µs
#  leaky_relu_bwd:  331.5µs ± 952.9ns, 329.8µs, 334.0µs
#  softplus_fwd:    236.2µs ± 3.344µs, 223.6µs, 246.4µs
#  softplus_bwd:    676.6µs ± 1.384ms, 438.5µs, 10.36ms
#  silu_jit_fwd:    183.6µs ± 26.65µs, 175.3µs, 353.8µs
#  silu_jit_bwd:    429.8µs ± 283.7µs, 363.4µs, 2.012ms
#  silu_native_fwd: 125.1µs ± 1.105µs, 124.0µs, 131.4µs
#  silu_native_bwd: 310.7µs ± 650.3ns, 309.7µs, 312.7µs
#  mish_naive_fwd:  438.2µs ± 38.26µs, 426.9µs, 698.3µs
#  mish_naive_bwd:  943.1µs ± 268.8µs, 901.3µs, 2.823ms
#  mish_jit_fwd:    376.1µs ± 6.112µs, 367.2µs, 391.9µs
#  mish_jit_bwd:    600.3µs ± 44.59µs, 590.9µs, 912.1µs
#  mish_cuda_fwd:   275.8µs ± 4.643µs, 271.8µs, 299.7µs
#  mish_cuda_bwd:   478.4µs ± 455.1ns, 477.4µs, 479.5µs
#  mish_native_fwd: 198.4µs ± 2.961µs, 194.5µs, 210.6µs
#  mish_native_bwd: 442.9µs ± 1.649µs, 441.5µs, 452.9µs
# Testing on torch.bfloat16:
#  relu_fwd:        113.0µs ± 27.41µs, 103.4µs, 288.0µs
#  relu_bwd:        343.6µs ± 191.9µs, 304.3µs, 1.467ms
#  leaky_relu_fwd:  103.3µs ± 4.374µs, 99.07µs, 117.2µs
#  leaky_relu_bwd:  348.4µs ± 225.9µs, 304.7µs, 1.833ms
#  softplus_fwd:    238.4µs ± 8.123µs, 232.8µs, 292.0µs
#  softplus_bwd:    403.4µs ± 50.14µs, 394.7µs, 754.4µs
#  silu_jit_fwd:    272.9µs ± 3.542µs, 269.2µs, 287.8µs
#  silu_jit_bwd:    974.2µs ± 527.8µs, 895.1µs, 4.669ms
#  silu_native_fwd: 141.6µs ± 5.399µs, 137.7µs, 171.9µs
#  silu_native_bwd: 315.5µs ± 1.828µs, 313.1µs, 325.8µs
#  mish_naive_fwd:  457.8µs ± 3.810µs, 453.4µs, 469.1µs
#  mish_naive_bwd:  880.9µs ± 109.0µs, 860.4µs, 1.631ms
#  mish_jit_fwd:    476.2µs ± 10.35µs, 465.2µs, 514.2µs
#  mish_jit_bwd:    1.344ms ± 76.96µs, 1.330ms, 1.882ms
#  mish_cuda_fwd:   476.2µs ± 10.35µs, 465.2µs, 514.2µs
#  mish_cuda_bwd:   1.344ms ± 76.96µs, 1.330ms, 1.882ms
#  mish_native_fwd: 217.2µs ± 3.298µs, 212.4µs, 230.9µs
#  mish_native_bwd: 453.6µs ± 937.9ns, 452.2µs, 456.8µs
# Testing on torch.float32:
#  relu_fwd:        186.2µs ± 5.063µs, 181.4µs, 200.2µs
#  relu_bwd:        463.6µs ± 160.6µs, 439.3µs, 1.588ms
#  leaky_relu_fwd:  182.6µs ± 6.764µs, 178.1µs, 214.1µs
#  leaky_relu_bwd:  480.9µs ± 225.0µs, 439.3µs, 1.987ms
#  softplus_fwd:    206.7µs ± 36.00µs, 199.1µs, 457.8µs
#  softplus_bwd:    511.1µs ± 489.3µs, 439.9µs, 3.936ms
#  silu_jit_fwd:    431.5µs ± 34.43µs, 421.1µs, 668.2µs
#  silu_jit_bwd:    1.597ms ± 426.6µs, 1.524ms, 4.538ms
#  silu_native_fwd: 181.4µs ± 4.683µs, 177.1µs, 196.2µs
#  silu_native_bwd: 463.0µs ± 100.1µs, 439.9µs, 1.055ms
#  mish_naive_fwd:  604.9µs ± 97.98µs, 586.2µs, 1.290ms
#  mish_naive_bwd:  1.374ms ± 149.6µs, 1.351ms, 2.421ms
#  mish_jit_fwd:    604.8µs ± 9.899µs, 597.9µs, 661.2µs
#  mish_jit_bwd:    2.152ms ± 420.4µs, 2.089ms, 5.095ms
#  mish_cuda_fwd:   282.1µs ± 5.811µs, 277.0µs, 308.6µs
#  mish_cuda_bwd:   516.9µs ± 203.4µs, 484.7µs, 1.941ms
#  mish_native_fwd: 204.1µs ± 4.255µs, 200.2µs, 220.9µs
#  mish_native_bwd: 466.8µs ± 1.205µs, 464.7µs, 469.7µs
# Testing on torch.float64:
#  relu_fwd:        396.0µs ± 5.002µs, 387.4µs, 412.0µs
#  relu_bwd:        722.0µs ± 148.4µs, 697.6µs, 1.761ms
#  leaky_relu_fwd:  391.1µs ± 24.25µs, 381.9µs, 558.0µs
#  leaky_relu_bwd:  757.8µs ± 400.1µs, 696.6µs, 3.558ms
#  softplus_fwd:    483.6µs ± 2.613µs, 479.5µs, 494.0µs
#  softplus_bwd:    792.4µs ± 2.110µs, 788.2µs, 797.4µs
#  silu_jit_fwd:    1.004ms ± 5.574µs, 996.2µs, 1.019ms
#  silu_jit_bwd:    3.251ms ± 3.316µs, 3.244ms, 3.258ms
#  silu_native_fwd: 384.4µs ± 6.609µs, 378.4µs, 408.2µs
#  silu_native_bwd: 702.2µs ± 54.50µs, 691.2µs, 1.084ms
#  mish_naive_fwd:  1.341ms ± 5.804µs, 1.333ms, 1.356ms
#  mish_naive_bwd:  2.775ms ± 3.794µs, 2.767ms, 2.784ms
#  mish_jit_fwd:    1.355ms ± 6.281µs, 1.345ms, 1.374ms
#  mish_jit_bwd:    4.606ms ± 329.3µs, 4.546ms, 6.911ms
#  mish_cuda_fwd:   719.2µs ± 4.328µs, 713.1µs, 732.7µs
#  mish_cuda_bwd:   979.4µs ± 1.141µs, 977.2µs, 983.3µs
#  mish_native_fwd: 643.2µs ± 3.712µs, 639.0µs, 656.1µs
#  mish_native_bwd: 1.103ms ± 1.083ms, 946.6µs, 8.682ms

# %%
profile('cuda', size='(64,10,256,256)', n_repeat=50)
# Out:
# Profiling over 50 runs after 10 warmup runs.
# Testing on torch.float16:
#  relu_fwd:        345.7µs ± 22.92µs, 337.4µs, 500.6µs
#  relu_bwd:        1.206ms ± 801.7ns, 1.205ms, 1.208ms
#  leaky_relu_fwd:  339.2µs ± 6.653µs, 333.2µs, 367.8µs
#  leaky_relu_bwd:  1.252ms ± 165.8µs, 1.205ms, 2.157ms
#  softplus_fwd:    793.0µs ± 5.494µs, 786.9µs, 819.3µs
#  softplus_bwd:    1.763ms ± 565.6µs, 1.624ms, 4.381ms
#  silu_jit_fwd:    928.1µs ± 57.32µs, 911.5µs, 1.326ms
#  silu_jit_bwd:    3.481ms ± 79.44µs, 3.465ms, 4.035ms
#  silu_native_fwd: 435.2µs ± 18.88µs, 426.5µs, 563.2µs
#  silu_native_bwd: 1.210ms ± 1.364µs, 1.207ms, 1.213ms
#  mish_naive_fwd:  1.621ms ± 5.045µs, 1.614ms, 1.636ms
#  mish_naive_bwd:  3.443ms ± 1.689µs, 3.440ms, 3.448ms
#  mish_jit_fwd:    1.635ms ± 6.902µs, 1.628ms, 1.655ms
#  mish_jit_bwd:    5.092ms ± 222.7µs, 5.057ms, 6.651ms
#  mish_cuda_fwd:   1.007ms ± 4.318µs, 1.003ms, 1.023ms
#  mish_cuda_bwd:   1.886ms ± 25.02µs, 1.882ms, 2.062ms
#  mish_native_fwd: 725.3µs ± 5.760µs, 719.0µs, 745.0µs
#  mish_native_bwd: 1.828ms ± 456.2µs, 1.736ms, 4.538ms
# Testing on torch.bfloat16:
#  relu_fwd:        342.9µs ± 8.077µs, 336.3µs, 375.1µs
#  relu_bwd:        1.192ms ± 1.099µs, 1.190ms, 1.194ms
#  leaky_relu_fwd:  344.9µs ± 57.53µs, 332.4µs, 746.5µs
#  leaky_relu_bwd:  1.208ms ± 110.8µs, 1.190ms, 1.984ms
#  softplus_fwd:    876.2µs ± 3.967µs, 871.0µs, 887.8µs
#  softplus_bwd:    1.586ms ± 261.7µs, 1.547ms, 3.418ms
#  silu_jit_fwd:    964.4µs ± 13.34µs, 954.2µs, 1.046ms
#  silu_jit_bwd:    3.543ms ± 260.1µs, 3.498ms, 5.357ms
#  silu_native_fwd: 493.2µs ± 5.378µs, 487.9µs, 508.1µs
#  silu_native_bwd: 1.235ms ± 114.2µs, 1.215ms, 2.034ms
#  mish_naive_fwd:  1.729ms ± 5.611µs, 1.723ms, 1.746ms
#  mish_naive_bwd:  3.370ms ± 926.4ns, 3.367ms, 3.372ms
#  mish_jit_fwd:    1.766ms ± 156.7µs, 1.734ms, 2.862ms
#  mish_jit_bwd:    5.202ms ± 1.808µs, 5.198ms, 5.206ms
#  mish_cuda_fwd:   1.766ms ± 156.7µs, 1.734ms, 2.862ms
#  mish_cuda_bwd:   5.202ms ± 1.808µs, 5.198ms, 5.206ms
#  mish_native_fwd: 792.2µs ± 43.30µs, 779.3µs, 1.093ms
#  mish_native_bwd: 1.835ms ± 398.3µs, 1.777ms, 4.623ms
# Testing on torch.float32:
#  relu_fwd:        656.4µs ± 8.308µs, 648.0µs, 690.0µs
#  relu_bwd:        1.795ms ± 443.3µs, 1.730ms, 4.899ms
#  leaky_relu_fwd:  651.0µs ± 22.76µs, 643.6µs, 807.4µs
#  leaky_relu_bwd:  1.732ms ± 885.0ns, 1.730ms, 1.734ms
#  softplus_fwd:    732.4µs ± 4.853µs, 726.1µs, 748.9µs
#  softplus_bwd:    1.777ms ± 304.7µs, 1.731ms, 3.910ms
#  silu_jit_fwd:    1.570ms ± 7.762µs, 1.560ms, 1.593ms
#  silu_jit_bwd:    6.028ms ± 1.859µs, 6.023ms, 6.031ms
#  silu_native_fwd: 647.5µs ± 4.605µs, 643.6µs, 662.3µs
#  silu_native_bwd: 1.795ms ± 431.0µs, 1.731ms, 4.812ms
#  mish_naive_fwd:  2.262ms ± 5.754µs, 2.254ms, 2.276ms
#  mish_naive_bwd:  5.353ms ± 68.34µs, 5.339ms, 5.831ms
#  mish_jit_fwd:    2.275ms ± 12.96µs, 2.264ms, 2.355ms
#  mish_jit_bwd:    8.260ms ± 2.682µs, 8.254ms, 8.267ms
#  mish_cuda_fwd:   1.033ms ± 3.757µs, 1.028ms, 1.044ms
#  mish_cuda_bwd:   1.945ms ± 285.3µs, 1.901ms, 3.942ms
#  mish_native_fwd: 731.5µs ± 6.499µs, 725.4µs, 751.3µs
#  mish_native_bwd: 1.877ms ± 360.6µs, 1.822ms, 4.401ms
# Testing on torch.float64:
#  relu_fwd:        1.473ms ± 11.72µs, 1.458ms, 1.519ms
#  relu_bwd:        2.810ms ± 301.2µs, 2.761ms, 4.919ms
#  leaky_relu_fwd:  1.463ms ± 7.289µs, 1.453ms, 1.496ms
#  leaky_relu_bwd:  2.765ms ± 2.925µs, 2.757ms, 2.772ms
#  softplus_fwd:    1.862ms ± 9.436µs, 1.854ms, 1.903ms
#  softplus_bwd:    3.131ms ± 55.11µs, 3.113ms, 3.514ms
#  silu_jit_fwd:    3.875ms ± 21.40µs, 3.847ms, 3.937ms
#  silu_jit_bwd:    12.86ms ± 8.358µs, 12.84ms, 12.87ms
#  silu_native_fwd: 1.451ms ± 7.297µs, 1.440ms, 1.467ms
#  silu_native_bwd: 2.741ms ± 2.316µs, 2.735ms, 2.747ms
#  mish_naive_fwd:  5.255ms ± 15.47µs, 5.236ms, 5.294ms
#  mish_naive_bwd:  11.01ms ± 9.056µs, 10.99ms, 11.03ms
#  mish_jit_fwd:    5.278ms ± 23.29µs, 5.248ms, 5.340ms
#  mish_jit_bwd:    18.06ms ± 10.16µs, 18.03ms, 18.07ms
#  mish_cuda_fwd:   2.766ms ± 10.25µs, 2.756ms, 2.805ms
#  mish_cuda_bwd:   3.872ms ± 1.643µs, 3.870ms, 3.879ms
#  mish_native_fwd: 2.487ms ± 7.042µs, 2.479ms, 2.514ms
#  mish_native_bwd: 3.750ms ± 1.615µs, 3.748ms, 3.757ms

# %% [markdown]
# # 25 iterations

# %%
profile('cuda', n_repeat=25, warmup=5)
# Out:
# Profiling over 25 runs after 5 warmup runs.
# Testing on torch.float16:
#  relu_fwd:        110.2µs ± 3.949µs, 104.6µs, 127.6µs
#  relu_bwd:        332.9µs ± 1.380µs, 330.8µs, 336.4µs
#  leaky_relu_fwd:  105.9µs ± 4.125µs, 101.5µs, 118.3µs
#  leaky_relu_bwd:  333.0µs ± 909.3ns, 331.5µs, 334.8µs
#  softplus_fwd:    239.3µs ± 4.721µs, 234.6µs, 254.6µs
#  softplus_bwd:    485.2µs ± 851.7ns, 483.6µs, 487.3µs
#  silu_jit_fwd:    195.0µs ± 4.587µs, 190.4µs, 208.9µs
#  silu_jit_bwd:    396.1µs ± 1.312µs, 394.1µs, 399.6µs
#  silu_native_fwd: 137.4µs ± 4.876µs, 132.9µs, 154.9µs
#  silu_native_bwd: 336.5µs ± 1.428µs, 334.3µs, 339.2µs
#  mish_naive_fwd:  463.4µs ± 4.393µs, 457.8µs, 475.7µs
#  mish_naive_bwd:  951.8µs ± 1.520µs, 948.6µs, 954.6µs
#  mish_jit_fwd:    382.8µs ± 13.21µs, 366.1µs, 410.5µs
#  mish_jit_bwd:    602.1µs ± 6.681µs, 594.0µs, 613.6µs
#  mish_cuda_fwd:   279.7µs ± 2.713µs, 276.9µs, 288.6µs
#  mish_cuda_bwd:   481.9µs ± 494.5ns, 480.9µs, 483.0µs
#  mish_native_fwd: 202.7µs ± 6.174µs, 196.9µs, 219.7µs
#  mish_native_bwd: 485.3µs ± 187.8µs, 443.2µs, 1.403ms
# Testing on torch.bfloat16:
#  relu_fwd:        108.9µs ± 2.716µs, 105.8µs, 117.7µs
#  relu_bwd:        308.5µs ± 5.832µs, 306.5µs, 336.8µs
#  leaky_relu_fwd:  111.5µs ± 18.03µs, 102.0µs, 194.5µs
#  leaky_relu_bwd:  346.8µs ± 131.9µs, 306.8µs, 946.1µs
#  softplus_fwd:    238.6µs ± 6.627µs, 224.6µs, 255.9µs
#  softplus_bwd:    398.0µs ± 3.199µs, 396.5µs, 413.3µs
#  silu_jit_fwd:    278.7µs ± 9.730µs, 273.7µs, 321.7µs
#  silu_jit_bwd:    899.2µs ± 1.001µs, 897.0µs, 901.1µs
#  silu_native_fwd: 141.4µs ± 3.067µs, 138.2µs, 155.3µs
#  silu_native_bwd: 316.6µs ± 994.9ns, 314.6µs, 318.7µs
#  mish_naive_fwd:  463.7µs ± 5.093µs, 457.7µs, 476.9µs
#  mish_naive_bwd:  886.4µs ± 115.0µs, 861.5µs, 1.450ms
#  mish_jit_fwd:    472.7µs ± 5.104µs, 469.0µs, 493.4µs
#  mish_jit_bwd:    1.333ms ± 980.9ns, 1.331ms, 1.335ms
#  mish_cuda_fwd:   472.7µs ± 5.104µs, 469.0µs, 493.4µs
#  mish_cuda_bwd:   1.333ms ± 980.9ns, 1.331ms, 1.335ms
#  mish_native_fwd: 216.2µs ± 4.515µs, 213.1µs, 231.0µs
#  mish_native_bwd: 578.1µs ± 471.1µs, 454.0µs, 2.759ms
# Testing on torch.float32:
#  relu_fwd:        188.6µs ± 11.87µs, 182.6µs, 242.8µs
#  relu_bwd:        443.3µs ± 2.525µs, 442.0µs, 455.5µs
#  leaky_relu_fwd:  186.3µs ± 8.050µs, 179.4µs, 208.4µs
#  leaky_relu_bwd:  477.3µs ± 148.4µs, 441.8µs, 1.197ms
#  softplus_fwd:    201.4µs ± 2.813µs, 199.2µs, 213.6µs
#  softplus_bwd:    443.8µs ± 556.2ns, 442.1µs, 444.6µs
#  silu_jit_fwd:    433.9µs ± 42.61µs, 420.9µs, 641.7µs
#  silu_jit_bwd:    1.598ms ± 340.3µs, 1.526ms, 3.265ms
#  silu_native_fwd: 183.8µs ± 6.046µs, 178.4µs, 207.0µs
#  silu_native_bwd: 444.1µs ± 1.057µs, 442.4µs, 446.9µs
#  mish_naive_fwd:  605.9µs ± 57.89µs, 589.4µs, 888.6µs
#  mish_naive_bwd:  1.379ms ± 110.4µs, 1.353ms, 1.919ms
#  mish_jit_fwd:    623.1µs ± 31.88µs, 602.1µs, 748.9µs
#  mish_jit_bwd:    2.208ms ± 545.6µs, 2.094ms, 4.881ms
#  mish_cuda_fwd:   288.1µs ± 4.234µs, 282.2µs, 301.7µs
#  mish_cuda_bwd:   497.2µs ± 36.47µs, 487.8µs, 675.7µs
#  mish_native_fwd: 206.6µs ± 7.626µs, 199.6µs, 228.7µs
#  mish_native_bwd: 468.8µs ± 1.729µs, 466.7µs, 473.4µs
# Testing on torch.float64:
#  relu_fwd:        394.0µs ± 2.772µs, 389.9µs, 402.3µs
#  relu_bwd:        704.4µs ± 1.475µs, 701.7µs, 706.7µs
#  leaky_relu_fwd:  390.3µs ± 4.394µs, 384.4µs, 405.9µs
#  leaky_relu_bwd:  704.0µs ± 1.945µs, 701.5µs, 709.9µs
#  softplus_fwd:    487.0µs ± 4.595µs, 481.6µs, 499.8µs
#  softplus_bwd:    808.8µs ± 2.523µs, 805.0µs, 816.4µs
#  silu_jit_fwd:    1.007ms ± 5.822µs, 998.8µs, 1.020ms
#  silu_jit_bwd:    3.313ms ± 289.5µs, 3.246ms, 4.731ms
#  silu_native_fwd: 383.1µs ± 2.271µs, 379.3µs, 389.2µs
#  silu_native_bwd: 697.2µs ± 1.293µs, 694.5µs, 699.4µs
#  mish_naive_fwd:  1.343ms ± 7.541µs, 1.334ms, 1.365ms
#  mish_naive_bwd:  2.793ms ± 3.074µs, 2.788ms, 2.800ms
#  mish_jit_fwd:    1.358ms ± 11.02µs, 1.345ms, 1.391ms
#  mish_jit_bwd:    4.605ms ± 218.8µs, 4.554ms, 5.676ms
#  mish_cuda_fwd:   718.2µs ± 3.071µs, 713.7µs, 727.2µs
#  mish_cuda_bwd:   981.9µs ± 461.1ns, 980.7µs, 982.8µs
#  mish_native_fwd: 645.6µs ± 8.100µs, 640.5µs, 679.6µs
#  mish_native_bwd: 1.038ms ± 434.8µs, 948.5µs, 3.168ms

# %%
profile('cuda', size='(64,10,256,256)', n_repeat=25, warmup=5)
# Out:
# Profiling over 25 runs after 5 warmup runs.
# Testing on torch.float16:
#  relu_fwd:        343.4µs ± 5.465µs, 337.7µs, 362.5µs
#  relu_bwd:        1.237ms ± 128.3µs, 1.209ms, 1.865ms
#  leaky_relu_fwd:  352.0µs ± 55.62µs, 336.8µs, 623.7µs
#  leaky_relu_bwd:  1.284ms ± 351.7µs, 1.210ms, 3.007ms
#  softplus_fwd:    793.2µs ± 6.308µs, 786.1µs, 813.8µs
#  softplus_bwd:    1.631ms ± 1.120µs, 1.629ms, 1.634ms
#  silu_jit_fwd:    923.6µs ± 7.414µs, 912.9µs, 936.7µs
#  silu_jit_bwd:    3.513ms ± 187.5µs, 3.470ms, 4.431ms
#  silu_native_fwd: 432.8µs ± 5.688µs, 425.4µs, 450.3µs
#  silu_native_bwd: 1.214ms ± 2.596µs, 1.211ms, 1.225ms
#  mish_naive_fwd:  1.628ms ± 10.02µs, 1.617ms, 1.654ms
#  mish_naive_bwd:  3.459ms ± 68.51µs, 3.443ms, 3.795ms
#  mish_jit_fwd:    1.637ms ± 7.579µs, 1.629ms, 1.659ms
#  mish_jit_bwd:    5.069ms ± 22.44µs, 5.062ms, 5.178ms
#  mish_cuda_fwd:   1.011ms ± 6.176µs, 1.005ms, 1.037ms
#  mish_cuda_bwd:   1.887ms ± 937.0ns, 1.885ms, 1.889ms
#  mish_native_fwd: 725.0µs ± 3.944µs, 722.3µs, 738.5µs
#  mish_native_bwd: 1.741ms ± 678.3ns, 1.740ms, 1.743ms
# Testing on torch.bfloat16:
#  relu_fwd:        341.4µs ± 4.669µs, 338.5µs, 361.5µs
#  relu_bwd:        1.198ms ± 527.0ns, 1.196ms, 1.199ms
#  leaky_relu_fwd:  339.9µs ± 5.819µs, 334.5µs, 355.5µs
#  leaky_relu_bwd:  1.198ms ± 592.2ns, 1.197ms, 1.199ms
#  softplus_fwd:    884.6µs ± 11.24µs, 874.9µs, 924.6µs
#  softplus_bwd:    1.697ms ± 485.6µs, 1.554ms, 3.543ms
#  silu_jit_fwd:    969.5µs ± 9.447µs, 960.4µs, 996.4µs
#  silu_jit_bwd:    3.564ms ± 241.0µs, 3.506ms, 4.737ms
#  silu_native_fwd: 495.6µs ± 4.966µs, 490.2µs, 509.7µs
#  silu_native_bwd: 1.226ms ± 1.480µs, 1.223ms, 1.229ms
#  mish_naive_fwd:  1.731ms ± 6.941µs, 1.724ms, 1.754ms
#  mish_naive_bwd:  3.410ms ± 161.6µs, 3.373ms, 4.201ms
#  mish_jit_fwd:    1.747ms ± 9.224µs, 1.737ms, 1.781ms
#  mish_jit_bwd:    5.237ms ± 140.4µs, 5.206ms, 5.925ms
#  mish_cuda_fwd:   1.747ms ± 9.224µs, 1.737ms, 1.781ms
#  mish_cuda_bwd:   5.237ms ± 140.4µs, 5.206ms, 5.925ms
#  mish_native_fwd: 785.7µs ± 3.999µs, 782.0µs, 798.3µs
#  mish_native_bwd: 1.784ms ± 513.0ns, 1.783ms, 1.786ms
# Testing on torch.float32:
#  relu_fwd:        657.2µs ± 6.767µs, 648.9µs, 678.1µs
#  relu_bwd:        1.741ms ± 1.039µs, 1.739ms, 1.743ms
#  leaky_relu_fwd:  649.4µs ± 5.055µs, 645.2µs, 664.0µs
#  leaky_relu_bwd:  1.741ms ± 1.232µs, 1.739ms, 1.745ms
#  softplus_fwd:    740.7µs ± 39.74µs, 727.1µs, 933.1µs
#  softplus_bwd:    1.742ms ± 914.0ns, 1.741ms, 1.744ms
#  silu_jit_fwd:    1.577ms ± 12.66µs, 1.565ms, 1.613ms
#  silu_jit_bwd:    6.036ms ± 2.476µs, 6.030ms, 6.041ms
#  silu_native_fwd: 647.3µs ± 3.762µs, 643.2µs, 657.4µs
#  silu_native_bwd: 1.743ms ± 1.069µs, 1.740ms, 1.744ms
#  mish_naive_fwd:  2.260ms ± 6.184µs, 2.253ms, 2.281ms
#  mish_naive_bwd:  5.354ms ± 1.858µs, 5.351ms, 5.359ms
#  mish_jit_fwd:    2.288ms ± 12.38µs, 2.271ms, 2.324ms
#  mish_jit_bwd:    8.486ms ± 1.073ms, 8.264ms, 13.75ms
#  mish_cuda_fwd:   1.031ms ± 3.069µs, 1.027ms, 1.042ms
#  mish_cuda_bwd:   1.977ms ± 317.9µs, 1.909ms, 3.535ms
#  mish_native_fwd: 730.1µs ± 2.990µs, 726.4µs, 738.1µs
#  mish_native_bwd: 1.836ms ± 1.567µs, 1.832ms, 1.839ms
# Testing on torch.float64:
#  relu_fwd:        1.474ms ± 9.574µs, 1.463ms, 1.504ms
#  relu_bwd:        2.780ms ± 2.923µs, 2.774ms, 2.785ms
#  leaky_relu_fwd:  1.465ms ± 6.609µs, 1.454ms, 1.478ms
#  leaky_relu_bwd:  2.778ms ± 2.793µs, 2.774ms, 2.783ms
#  softplus_fwd:    1.860ms ± 6.190µs, 1.852ms, 1.879ms
#  softplus_bwd:    3.191ms ± 6.233µs, 3.183ms, 3.207ms
#  silu_jit_fwd:    3.881ms ± 22.20µs, 3.856ms, 3.939ms
#  silu_jit_bwd:    12.87ms ± 9.373µs, 12.85ms, 12.89ms
#  silu_native_fwd: 1.449ms ± 6.517µs, 1.440ms, 1.469ms
#  silu_native_bwd: 2.755ms ± 3.214µs, 2.748ms, 2.761ms
#  mish_naive_fwd:  5.246ms ± 6.522µs, 5.236ms, 5.267ms
#  mish_naive_bwd:  11.08ms ± 8.765µs, 11.06ms, 11.10ms
#  mish_jit_fwd:    5.283ms ± 12.98µs, 5.267ms, 5.310ms
#  mish_jit_bwd:    18.07ms ± 9.638µs, 18.06ms, 18.10ms
#  mish_cuda_fwd:   2.761ms ± 5.812µs, 2.755ms, 2.780ms
#  mish_cuda_bwd:   3.885ms ± 986.4ns, 3.882ms, 3.886ms
#  mish_native_fwd: 2.489ms ± 12.01µs, 2.480ms, 2.536ms
#  mish_native_bwd: 3.758ms ± 1.035µs, 3.757ms, 3.761ms
